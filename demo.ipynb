# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set(style="whitegrid")

# %%
df = pd.read_csv(r"D:\Desktop folders\Datasets\Dataset Samples\car_price_prediction_.csv")

# %%
df
# Out:
#       Car ID   Brand  Year  Engine Size Fuel Type Transmission  Mileage  \
# 0          1   Tesla  2016          2.3    Petrol       Manual   114832
# 1          2     BMW  2018          4.4  Electric       Manual   143190
# 2          3    Audi  2013          4.5  Electric       Manual   181601
# 3          4   Tesla  2011          4.1    Diesel    Automatic    68682
# 4          5    Ford  2009          2.6    Diesel       Manual   223009
# ...      ...     ...   ...          ...       ...          ...      ...
# 2495    2496    Audi  2020          2.4    Petrol    Automatic    22650
# 2496    2497    Audi  2001          5.7    Hybrid       Manual    77701
# 2497    2498    Ford  2021          1.1    Hybrid       Manual   272827
# 2498    2499    Audi  2002          4.5    Diesel       Manual   229164
# 2499    2500  Toyota  2005          4.6    Diesel    Automatic    80978
#
#      Condition     Price     Model
# 0          New  26613.92   Model X
# ...

# %%
# 1. Distribution of Car Prices
plt.figure(figsize=(8, 5))
sns.histplot(df['Price'], kde=True, bins=30, color='blue')
plt.title("Distribution of Car Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
# 2. Condition-wise Price Distribution
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Condition', y='Price', palette='pastel')
plt.title("Condition-wise Price Distribution")
plt.xlabel("Condition")
plt.ylabel("Price")
plt.show()
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_14244\1787456903.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Condition', y='Price', palette='pastel')

# %%
# 3. Brand-wise Car Counts
plt.figure(figsize=(8, 5))
sns.countplot(data=df, y='Brand', palette='viridis', order=df['Brand'].value_counts().index)
plt.title("Brand-wise Car Counts")
plt.xlabel("Count")
plt.ylabel("Brand")
plt.show()
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_14244\2947176514.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='Brand', palette='viridis', order=df['Brand'].value_counts().index)

# %%
# 4. Average Price by Fuel Type
plt.figure(figsize=(8, 5))
avg_price_fuel = df.groupby('Fuel Type')['Price'].mean().sort_values()
sns.barplot(x=avg_price_fuel.index, y=avg_price_fuel.values, palette='coolwarm')
plt.title("Average Price by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Average Price")
plt.show()
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_14244\4123572811.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_fuel.index, y=avg_price_fuel.values, palette='coolwarm')

# %%
# 5. Yearly Trend in Car Listings
plt.figure(figsize=(10, 5))
yearly_trend = df['Year'].value_counts().sort_index()
plt.plot(yearly_trend.index, yearly_trend.values, marker='o', color='purple')
plt.title("Yearly Trend in Car Listings")
plt.xlabel("Year")
plt.ylabel("Number of Listings")
plt.grid(True)
plt.show()

# %%
# 6. Mileage vs. Price Relationship
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Mileage', y='Price', alpha=0.7, color='green')
plt.title("Mileage vs. Price Relationship")
plt.xlabel("Mileage")
plt.ylabel("Price")
plt.show()

# %%
# 7. Price Distribution by Transmission Type
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Transmission', y='Price', palette='muted')
plt.title("Price Distribution by Transmission Type")
plt.xlabel("Transmission")
plt.ylabel("Price")
plt.show()
# Out:
# C:\Users\anike\AppData\Local\Temp\ipykernel_14244\683811514.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Transmission', y='Price', palette='muted')

# %%
# 8. Engine Size vs. Price Relationship by Fuel Type
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Engine Size', y='Price', hue='Fuel Type', alpha=0.7, palette='Set2')
plt.title("Engine Size vs. Price Relationship by Fuel Type")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.legend(title="Fuel Type")
plt.show()

# %%
# 9. Correlation Heatmap of Numeric Features
plt.figure(figsize=(8, 6))
corr_matrix = df[['Year', 'Engine Size', 'Mileage', 'Price']].corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("Correlation Heatmap of Numeric Features")
plt.show()

# %%
# 10. Condition-wise Average Price Trend Over Years
plt.figure(figsize=(10, 5))
condition_year_trend = df.groupby(['Year', 'Condition'])['Price'].mean().reset_index()
sns.lineplot(data=condition_year_trend, x='Year', y='Price', hue='Condition', palette='tab10')
plt.title("Condition-wise Average Price Trend Over Years")
plt.xlabel("Year")
plt.ylabel("Average Price")
plt.legend(title="Condition")
plt.show()

# %%
condition_year_trend = df.groupby(['Year', 'Condition'])['Price'].mean()
condition_year_trend
# Out:
# Year  Condition
# 2000  Like New     47859.836667
#       New          52490.820714
#       Used         60174.486207
# 2001  Like New     52783.797297
#       New          51700.486364
#                        ...
# 2022  New          52606.202609
#       Used         59383.073871
# 2023  Like New     52179.131818
#       New          46019.623810
#       Used         58289.992857
# Name: Price, Length: 72, dtype: float64
