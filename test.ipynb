# %%
import pandas as pd

# %%
x=pd.read_csv("expert_dataset_all.csv")

# %%
x.head(10)
# Out:
#   expert_id              name                    expertise  \
# 0    EX-001      Rachita Mane     Aeronautical Engineering
# 1    EX-002  Ethan Narasimhan  Instrumentation Engineering
# 2    EX-003      Indali Saraf     Aeronautical Engineering
# 3    EX-004    George Prashad     Aeronautical Engineering
# 4    EX-005     Ekansh Butala                    Chemistry
# 5    EX-006         Tejas Ben                   Psychology
# 6    EX-007      Wakeeta Bumb     Aeronautical Engineering
# 7    EX-008     Utkarsh Ratti                      Physics
# 8    EX-009        Yatin Lala         Chemical Engineering
# 9    EX-010       Ekani Ahuja                  Mathematics
#
#                       highest_qualification  \
# 0           PhD in Aeronautical Engineering
# 1        Master's Degree in Control Systems
# 2  Master's Degree in Aerospace Engineering
# 3           PhD in Aeronautical Engineering
# 4      Master's Degree in Organic Chemistry
# ...
